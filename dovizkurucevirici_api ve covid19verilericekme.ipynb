# %%
import requests
import json

# %%
dir(requests)

# %%
r = requests.get('http://httpbin.org/get')
r.text
# Out:
# '{\n  "args": {}, \n  "headers": {\n    "Accept": "*/*", \n    "Accept-Encoding": "gzip, deflate", \n    "Host": "httpbin.org", \n    "User-Agent": "python-requests/2.23.0", \n    "X-Amzn-Trace-Id": "Root=1-62652bf2-73958c7e62ffd8be3b8e258a"\n  }, \n  "origin": "35.197.115.61", \n  "url": "http://httpbin.org/get"\n}\n'

# %%
r.json()
# Out:
# {'args': {},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.23.0',
#   'X-Amzn-Trace-Id': 'Root=1-62652bf2-73958c7e62ffd8be3b8e258a'},
#  'origin': '35.197.115.61',
#  'url': 'http://httpbin.org/get'}

# %%
r = requests.get('http://httpbin.org/get', params={"kategori":"egitim","kurs":"python"})
r.json()
# Out:
# {'args': {'kategori': 'egitim', 'kurs': 'python'},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.23.0',
#   'X-Amzn-Trace-Id': 'Root=1-62652c98-160dc63965781be706b0f9e7'},
#  'origin': '35.197.115.61',
#  'url': 'http://httpbin.org/get?kategori=egitim&kurs=python'}

# %%
r = requests.post("http://httpbin.org/post", data={"kullanici":"prodem","sifre":"python"})
r.json()
# Out:
# {'args': {},
#  'data': '',
#  'files': {},
#  'form': {'kullanici': 'prodem', 'sifre': 'python'},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Content-Length': '29',
#   'Content-Type': 'application/x-www-form-urlencoded',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.23.0',
#   'X-Amzn-Trace-Id': 'Root=1-62652d17-0b32d07071d2b0ee09190e54'},
#  'json': None,
#  'origin': '35.197.115.61',
#  'url': 'http://httpbin.org/post'}

# %%
uri="http://httpbin.org/post"
mydata={"no":1,"ad":"can","yas":48,"adres":{"sehir":"sakarya","ilce":"serdivan"}}
r = requests.post(uri, data=json.dumps(mydata))
r.json()
# Out:
# {'args': {},
#  'data': '{"no": 1, "ad": "can", "yas": 48, "adres": {"sehir": "sakarya", "ilce": "serdivan"}}',
#  'files': {},
#  'form': {},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Content-Length': '84',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.23.0',
#   'X-Amzn-Trace-Id': 'Root=1-62652ead-2eee9d6e4b9955b9559e549e'},
#  'json': {'ad': 'can',
#   'adres': {'ilce': 'serdivan', 'sehir': 'sakarya'},
#   'no': 1,
#   'yas': 48},
#  'origin': '35.197.115.61',
#  'url': 'http://httpbin.org/post'}

# %%
import requests
import json
url = "https://api.covid19api.com/summary"

payload = {}
headers = {}

response = requests.request("GET",url, headers=headers, data = payload)

result = json.loads(response.text)

print(result)
# Out:
# {'ID': 'e1be61e1-034b-47bf-bc7e-d9e0778e98b5', 'Message': '', 'Global': {'NewConfirmed': 600912, 'TotalConfirmed': 507637535, 'NewDeaths': 2262, 'TotalDeaths': 6211253, 'NewRecovered': 0, 'TotalRecovered': 0, 'Date': '2022-04-24T09:09:56.322Z'}, 'Countries': [{'ID': '37cb00d0-c4af-4855-a96d-ed75845325dc', 'Country': 'Afghanistan', 'CountryCode': 'AF', 'Slug': 'afghanistan', 'NewConfirmed': 10, 'TotalConfirmed': 178648, 'NewDeaths': 1, 'TotalDeaths': 7681, 'NewRecovered': 0, 'TotalRecovered': 0, 'Date': '2022-04-24T09:09:56.322Z', 'Premium': {}}, {'ID': '5eb9c387-5c50-4c0a-8bd0-d5990274b593', 'Country': 'Albania', 'CountryCode': 'AL', 'Slug': 'albania', 'NewConfirmed': 54, 'TotalConfirmed': 274791, 'NewDeaths': 0, 'TotalDeaths': 3496, 'NewRecovered': 0, 'TotalRecovered': 0, 'Date': '2022-04-24T09:09:56.322Z', 'Premium': {}}, {'ID': 'f369baae-0f93-4705-b331-56c0aeabd2ee', 'Country': 'Algeria', 'CountryCode': 'DZ', 'Slug': 'algeria', 'NewConfirmed': 0, 'TotalConfirmed': 265761, 'NewDeat
# ...

# %%
url = "https://api.covid19api.com/total/country/Turkey/status/confirmed"

payload = {}
headers = {}

response = requests.request("GET",url, headers=headers, data = payload)

result = json.loads(response.text)

print(result)
# Out:
# [{'Country': 'Turkey', 'CountryCode': '', 'Province': '', 'City': '', 'CityCode': '', 'Lat': '0', 'Lon': '0', 'Cases': 0, 'Status': 'confirmed', 'Date': '2020-01-22T00:00:00Z'}, {'Country': 'Turkey', 'CountryCode': '', 'Province': '', 'City': '', 'CityCode': '', 'Lat': '0', 'Lon': '0', 'Cases': 0, 'Status': 'confirmed', 'Date': '2020-01-23T00:00:00Z'}, {'Country': 'Turkey', 'CountryCode': '', 'Province': '', 'City': '', 'CityCode': '', 'Lat': '0', 'Lon': '0', 'Cases': 0, 'Status': 'confirmed', 'Date': '2020-01-24T00:00:00Z'}, {'Country': 'Turkey', 'CountryCode': '', 'Province': '', 'City': '', 'CityCode': '', 'Lat': '0', 'Lon': '0', 'Cases': 0, 'Status': 'confirmed', 'Date': '2020-01-25T00:00:00Z'}, {'Country': 'Turkey', 'CountryCode': '', 'Province': '', 'City': '', 'CityCode': '', 'Lat': '0', 'Lon': '0', 'Cases': 0, 'Status': 'confirmed', 'Date': '2020-01-26T00:00:00Z'}, {'Country': 'Turkey', 'CountryCode': '', 'Province': '', 'City': '', 'CityCode': '', 'Lat': '0', 'Lon': '0', 'Ca
# ...

# %%
url="http://hasanadiguzel.com.tr/api/kurgetir"
r=requests.get(url)

# %%
r.status_code
# Out:
# 200

# %%
r.text
# Out:
# '{"Developer":{"name":"Hasan ADIGÜZEL","website":"http:\\/\\/hasanadiguzel.com.tr","email":"iletisim@hasanadiguzel.com.tr"},"TCMB_AnlikKurBilgileri":[{"Isim":"ABD DOLARI","CurrencyName":"US DOLLAR","ForexBuying":14.7068,"ForexSelling":14.7333,"BanknoteBuying":14.6965,"BanknoteSelling":14.7554,"CrossRateUSD":"","CrossRateOther":""},{"Isim":"AVUSTRALYA DOLARI","CurrencyName":"AUSTRALIAN DOLLAR","ForexBuying":10.7212,"ForexSelling":10.7911,"BanknoteBuying":10.6719,"BanknoteSelling":10.8559,"CrossRateUSD":1.3685,"CrossRateOther":""},{"Isim":"DANİMARKA KRONU","CurrencyName":"DANISH KRONE","ForexBuying":2.1339,"ForexSelling":2.1443,"BanknoteBuying":2.1324,"BanknoteSelling":2.1493,"CrossRateUSD":6.8814,"CrossRateOther":""},{"Isim":"EURO","CurrencyName":"EURO","ForexBuying":15.9017,"ForexSelling":15.9304,"BanknoteBuying":15.8906,"BanknoteSelling":15.9543,"CrossRateUSD":"","CrossRateOther":1.0813},{"Isim":"İNGİLİZ STERLİNİ","CurrencyName":"POUND STERLING","ForexBuying":18.9495,"ForexSelling":
# ...

# %%
result = json.loads(r.text)
ara=result["TCMB_AnlikKurBilgileri"]
k=0
for i in ara:
  print(ara[k]["Isim"])
  k=k+1

# %%
result = json.loads(r.text)
print(result)
# Out:
# {'Developer': {'name': 'Hasan ADIGÜZEL', 'website': 'http://hasanadiguzel.com.tr', 'email': 'iletisim@hasanadiguzel.com.tr'}, 'TCMB_AnlikKurBilgileri': [{'Isim': 'ABD DOLARI', 'CurrencyName': 'US DOLLAR', 'ForexBuying': 14.7068, 'ForexSelling': 14.7333, 'BanknoteBuying': 14.6965, 'BanknoteSelling': 14.7554, 'CrossRateUSD': '', 'CrossRateOther': ''}, {'Isim': 'AVUSTRALYA DOLARI', 'CurrencyName': 'AUSTRALIAN DOLLAR', 'ForexBuying': 10.7212, 'ForexSelling': 10.7911, 'BanknoteBuying': 10.6719, 'BanknoteSelling': 10.8559, 'CrossRateUSD': 1.3685, 'CrossRateOther': ''}, {'Isim': 'DANİMARKA KRONU', 'CurrencyName': 'DANISH KRONE', 'ForexBuying': 2.1339, 'ForexSelling': 2.1443, 'BanknoteBuying': 2.1324, 'BanknoteSelling': 2.1493, 'CrossRateUSD': 6.8814, 'CrossRateOther': ''}, {'Isim': 'EURO', 'CurrencyName': 'EURO', 'ForexBuying': 15.9017, 'ForexSelling': 15.9304, 'BanknoteBuying': 15.8906, 'BanknoteSelling': 15.9543, 'CrossRateUSD': '', 'CrossRateOther': 1.0813}, {'Isim': 'İNGİLİZ STERLİNİ', 
# ...

# %%
SatisTuru=input("Satılmak İstenen Döviz Türü: ")
miktar=int(input(f"Bozdurulacak {SatisTuru} Miktarı: "))
result = json.loads(r.text)
ara=result["TCMB_AnlikKurBilgileri"]
k=-1
for i in ara:
  k=k+1
  if ara[k]["Isim"]==SatisTuru:
    indis=k

satis=ara[indis]["ForexBuying"]
print("Kur: ",satis)
print("Değeri: ", satis*miktar)
# Out:
# Satılmak İstenen Döviz Türü: EURO
# Bozdurulacak EURO Miktarı: 100
# Kur:  15.9017
# Değeri:  1590.17
